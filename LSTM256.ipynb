# %%
# %matplotlib inline
from numpy import linalg as LA
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import torch 

np.random.seed(2)

# %%
# %config InlineBackend.figure_format = 'retina'
plt.style.use('dark_background')

# %%
def read_turbine(t_no, sensors = range(3)):
    df = [ pd.read_hdf(DATA_PATH, key = 'Turbine{:02d}/Sensor{:02d}'.format(t_no, j))
        for j in sensors
    ]
    return df[0].index, np.hstack([col.values.astype(float) for col in df])

# %%
WIND, ROTOR, POWER = 1, 2, 3
DATA_PATH = "../Data/key_value_scada.h5"

# %%
def train_test():
    t_no = 1
    timestamp, X = read_turbine(t_no, sensors = [WIND, ROTOR, POWER])
    X[:, 2] /= 100 # roughly normalize second column
    N, I = X.shape

    X_training = X[4767:12767 , :]
    X_train = X_training[~np.isnan(X_training).any(axis = 1)]

    return X, X_train, timestamp

# %%
X, X_train, timestamp = train_test()

# %%
ax = plt.figure(figsize = (13, 8))
ax = plt.axes(projection='3d')

ax.plot3D(X_train[:,0], X_train[:,1], X_train[:,2], '.', alpha=0.4, ms=1)

ax.set_title('Power Curve')
ax.set_xlabel('Wind Speed')
ax.set_ylabel('Rotor Speed')
ax.set_zlabel('Grid Power')
#ax.set_xlabel('Rüzgar Hızı')
#ax.set_ylabel('Döneç Hızı')
#ax.set_zlabel('Üretilen Güç')

ax.view_init(azim=240)
plt.show()

# %%
from __future__ import print_function
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train = X_train[:,0].reshape(len(X_train), 1)
output = X_train[:,1:3]

# %%
# Recurrent neural network (many-to-one)
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        # Set initial hidden and cell states 
        
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))  # out: tensor of shape (batch_size, seq_length, hidden_size)
        #print (out.shape, out[:, -1, :].shape)
        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

# %%
# Hyper-parameters
sequence_length = 1
input_size = 1
hidden_size = 256
num_layers = 2
num_classes = 2
batch_size = 100
num_epochs = 10
learning_rate = 0.01

# %%
model = LSTM(input_size, hidden_size, num_layers, num_classes).to(device)
print (model)

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# LSTM(
#   (lstm): LSTM(1, 256, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
for epoch in range(num_epochs):
    for i in range(int((len(X_train)-batch_size)/10)):
        train_ = train[i*10:i*10+batch_size]
        train_ = torch.Tensor(train_)
        train_ = train_.reshape(-1, sequence_length, input_size).to(device)
        
        
        output_ = output[i*10:i*10+batch_size]
        output_ = torch.Tensor(output_)
        #print (output_.shape)
        #output_ = output_.reshape(-1, sequence_length, input_size).to(device)
        # Forward pass
        results_ = model(train_)
        loss = criterion(results_, output_)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, int((len(X_train)-batch_size)/10), loss.item()))
# Out:
# Epoch [1/10], Step [100/790], Loss: 4.8610
# Epoch [1/10], Step [200/790], Loss: 1.3193
# Epoch [1/10], Step [300/790], Loss: 0.5678
# Epoch [1/10], Step [400/790], Loss: 9.1397
# Epoch [1/10], Step [500/790], Loss: 2.9983
# Epoch [1/10], Step [600/790], Loss: 0.7196
# Epoch [1/10], Step [700/790], Loss: 1.6087
# Epoch [2/10], Step [100/790], Loss: 0.4546
# Epoch [2/10], Step [200/790], Loss: 0.5484
# Epoch [2/10], Step [300/790], Loss: 0.1219
# Epoch [2/10], Step [400/790], Loss: 9.1783
# Epoch [2/10], Step [500/790], Loss: 2.6327
# Epoch [2/10], Step [600/790], Loss: 0.6554
# Epoch [2/10], Step [700/790], Loss: 1.2515
# Epoch [3/10], Step [100/790], Loss: 0.4087
# Epoch [3/10], Step [200/790], Loss: 0.5859
# Epoch [3/10], Step [300/790], Loss: 0.1318
# Epoch [3/10], Step [400/790], Loss: 9.4518
# Epoch [3/10], Step [500/790], Loss: 2.5482
# Epoch [3/10], Step [600/790], Loss: 0.7381
# Epoch [3/10], Step [700/790], Loss: 0.9301
# Epoch [4/10], Step [100/790], Loss: 0.5590
# Epoch [4/10], Step [200/790], Loss: 0.5809
# Epoch [4/10], Step [300/790], Loss: 0.1752
# Epoch [4/10], Step [400/790], Loss: 9.6765
# Epoch [4/10], Step [500/790], Loss: 2.5455
# Epoch [4/10], Step [600/790], Loss: 0.6811
# Epoch [4/10], Step [700/790], Loss: 0.8106
# Epoch [5/10], Step [100/790], Loss: 0.5751
# Epoch [5/10], Step [200/790], Loss: 0.6140
# Epoch [5/10], Step [300/790], Loss: 0.1236
# Epoch [5/10], Step [400/790], Loss: 9.8888
# Epoch [5/10], Step [500/790], Loss: 2.6297
# Epoch [5/10], Step [600/790], Loss: 0.6787
# Epoch [5/10], Step [700/790], Loss: 0.7549
# Epoch [6/10], Step [100/790], Loss: 0.8051
# Epoch [6/10], Step [200/790], Loss: 0.7285
# Epoch [6/10], Step [300/790], Loss: 0.1157
# Epoch [6/10], Step [400/790], Loss: 10.1107
# Epoch [6/10], Step [500/790], Loss: 2.7802
# Epoch [6/10], Step [600/790], Loss: 0.6588
# Epoch [6/10], Step [700/790], Loss: 0.8423
# Epoch [7/10], Step [100/790], Loss: 0.7776
# Epoch [7/10], Step [200/790], Loss: 0.7712
# Epoch [7/10], Step [300/790], Loss: 0.0984
# Epoch [7/10], Step [400/790], Loss: 9.8623
# Epoch [7/10], Step [500/790], Loss: 2.7962
# Epoch [7/10], Step [600/790], Loss: 0.7028
# Epoch [7/10], Step [700/790], Loss: 0.9972
# Epoch [8/10], Step [100/790], Loss: 0.8288
# Epoch [8/10], Step [200/790], Loss: 0.7895
# Epoch [8/10], Step [300/790], Loss: 0.1180
# Epoch [8/10], Step [400/790], Loss: 10.0823
# Epoch [8/10], Step [500/790], Loss: 2.6936
# Epoch [8/10], Step [600/790], Loss: 0.6842
# Epoch [8/10], Step [700/790], Loss: 0.8817
# Epoch [9/10], Step [100/790], Loss: 0.3199
# Epoch [9/10], Step [200/790], Loss: 0.7005
# Epoch [9/10], Step [300/790], Loss: 0.2130
# Epoch [9/10], Step [400/790], Loss: 10.5343
# Epoch [9/10], Step [500/790], Loss: 2.6213
# Epoch [9/10], Step [600/790], Loss: 0.7505
# Epoch [9/10], Step [700/790], Loss: 0.7314
# Epoch [10/10], Step [100/790], Loss: 0.2424
# Epoch [10/10], Step [200/790], Loss: 0.6794
# Epoch [10/10], Step [300/790], Loss: 0.2216
# Epoch [10/10], Step [400/790], Loss: 11.0353
# Epoch [10/10], Step [500/790], Loss: 2.5645
# Epoch [10/10], Step [600/790], Loss: 0.7567
# Epoch [10/10], Step [700/790], Loss: 0.7711

# %%
with torch.no_grad():
    X_ = X[:,0].reshape(len(X), 1)
    Y_ = X[:,1:3]
    test_ = torch.Tensor(X_)
    test_ = test_.reshape(-1, sequence_length, input_size).to(device)
    prediction_ = model(test_)
    
prediction = prediction_.detach().numpy()

# %%
ax = plt.figure(figsize = (13, 8))
ax = plt.axes(projection='3d')

ax.plot3D(X[:,0], prediction[:,0], prediction[:,1], 'b.', alpha=1, ms=2)
ax.plot3D(X[:,0], X[:,1], X[:,2], 'r.', alpha=0.1, ms=1)

ax.set_title('LSTM - Power Curve')
ax.set_xlabel('Wind Speed')
ax.set_ylabel('Rotor Speed')
ax.set_zlabel('Grid Power')
#ax.set_xlabel('Rüzgar Hızı')
#ax.set_ylabel('Döneç Hızı')
#ax.set_zlabel('Üretilen Güç')

ax.view_init(azim=240)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("Rotor Speed Real and Generated")
plt.plot(timestamp, X[:,1], 'b.', alpha=0.2, ms = 2, label = 'Test Data')
plt.plot(timestamp, prediction[:,0], 'r.', alpha=0.2, ms = 2, label = 'LSTM Prediction')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("Grid Power Real and Generated")
plt.plot(timestamp, X[:,2], 'b.', alpha=0.1, ms = 2, label = 'Test Data')
plt.plot(timestamp, prediction[:,1], 'r.', alpha=0.1, ms = 2, label = 'LSTM Prediction')
plt.legend(loc='upper right')
plt.show()

# %%
E = X[:,1:3] - prediction
E_norm = np.linalg.norm(E, axis = 1)
plt.figure(figsize=(15,5))
plt.plot(timestamp, E_norm)
plt.show()

# %%
smoothing_coefficient = 0.99
average = np.zeros(len(E_norm))
for i in range(len(E_norm)):
        if (i == 0):
            average[i] = E_norm[i]
        else:
            average[i] = average[i - 1]*smoothing_coefficient + E_norm[i]*(1 - smoothing_coefficient)

# %%
plt.figure(figsize=(15,5))
plt.title("LSTM Anomaly Graph")
plt.plot(timestamp, E_norm,'b', alpha=0.4, ms = 2, label='Single Anomaly')
plt.plot(timestamp, average, 'r', alpha=1, ms = 2, label='Collective Anomaly')
plt.legend(loc='upper right')
plt.axvline('2017-06-21', color='black')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("Generated Power")
plt.plot(timestamp, X[:,2], '.', alpha=0.2, ms = 2)
plt.show()

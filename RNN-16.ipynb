# %%
# %matplotlib inline
from numpy import linalg as LA
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import torch 

np.random.seed(2)

# %%
# %config InlineBackend.figure_format = 'retina'
plt.style.use('dark_background')

# %%
def read_turbine(t_no, sensors = range(3)):
    df = [ pd.read_hdf(DATA_PATH, key = 'Turbine{:02d}/Sensor{:02d}'.format(t_no, j))
        for j in sensors
    ]
    return df[0].index, np.hstack([col.values.astype(float) for col in df])

# %%
WIND, ROTOR, POWER = 1, 2, 3
DATA_PATH = "../Data/key_value_scada.h5"

# %%
def train_test():
    t_no = 1
    timestamp, X = read_turbine(t_no, sensors = [WIND, ROTOR, POWER])
    X[:, 2] /= 100 # roughly normalize second column
    N, I = X.shape

    X_training = X[4767:12767 , :]
    X_train = X_training[~np.isnan(X_training).any(axis = 1)]

    return X, X_train, timestamp

# %%
X, X_train, timestamp = train_test()

# %%
ax = plt.figure(figsize = (13, 8))
ax = plt.axes(projection='3d')

ax.plot3D(X_train[:,0], X_train[:,1], X_train[:,2], '.', alpha=0.4, ms=1)

ax.set_title('Power Curve')
ax.set_xlabel('Wind Speed')
ax.set_ylabel('Rotor Speed')
ax.set_zlabel('Grid Power')
#ax.set_xlabel('Rüzgar Hızı')
#ax.set_ylabel('Döneç Hızı')
#ax.set_zlabel('Üretilen Güç')

ax.view_init(azim=240)
plt.show()

# %%
from __future__ import print_function
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import numpy as np
import matplotlib
#matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train = X_train[:,0].reshape(len(X_train), 1)
output = X_train[:,1:3]

# %%
# Recurrent neural network (many-to-one)
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        # Set initial hidden and cell states 
        
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        #c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        # Forward propagate LSTM
        out, _ = self.rnn(x, h0)  # out: tensor of shape (batch_size, seq_length, hidden_size)
        #print (out.shape, out[:, -1, :].shape)
        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

# %%
# Hyper-parameters
sequence_length = 1
input_size = 1
hidden_size = 16
num_layers = 1
num_classes = 2
batch_size = 1000
num_epochs = 10
learning_rate = 0.01

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)
print (model)

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# RNN(
#   (rnn): RNN(1, 16, batch_first=True)
#   (fc): Linear(in_features=16, out_features=2, bias=True)
# )

# %%
for epoch in range(num_epochs):
    for i in range(int((len(X_train)-batch_size)/10)):
        train_ = train[i*10:i*10+batch_size]
        train_ = torch.Tensor(train_)
        train_ = train_.reshape(-1, sequence_length, input_size).to(device)
        
        
        output_ = output[i*10:i*10+batch_size]
        output_ = torch.Tensor(output_)
        #print (output_.shape)
        #output_ = output_.reshape(-1, sequence_length, input_size).to(device)
        # Forward pass
        results_ = model(train_)
        loss = criterion(results_, output_)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, int((len(X_train)-batch_size)/10), loss.item()))
# Out:
# Epoch [1/10], Step [100/700], Loss: 28.7716
# Epoch [1/10], Step [200/700], Loss: 18.5331
# Epoch [1/10], Step [300/700], Loss: 6.0775
# Epoch [1/10], Step [400/700], Loss: 3.7493
# Epoch [1/10], Step [500/700], Loss: 3.4008
# Epoch [1/10], Step [600/700], Loss: 8.0532
# Epoch [1/10], Step [700/700], Loss: 2.0584
# Epoch [2/10], Step [100/700], Loss: 1.0916
# Epoch [2/10], Step [200/700], Loss: 0.6898
# Epoch [2/10], Step [300/700], Loss: 0.7897
# Epoch [2/10], Step [400/700], Loss: 1.9224
# Epoch [2/10], Step [500/700], Loss: 1.0452
# Epoch [2/10], Step [600/700], Loss: 7.1187
# Epoch [2/10], Step [700/700], Loss: 0.7189
# Epoch [3/10], Step [100/700], Loss: 0.5683
# Epoch [3/10], Step [200/700], Loss: 0.3880
# Epoch [3/10], Step [300/700], Loss: 0.5518
# Epoch [3/10], Step [400/700], Loss: 1.8116
# Epoch [3/10], Step [500/700], Loss: 0.9609
# Epoch [3/10], Step [600/700], Loss: 6.9852
# Epoch [3/10], Step [700/700], Loss: 0.6086
# Epoch [4/10], Step [100/700], Loss: 0.5211
# Epoch [4/10], Step [200/700], Loss: 0.3424
# Epoch [4/10], Step [300/700], Loss: 0.5264
# Epoch [4/10], Step [400/700], Loss: 1.7788
# Epoch [4/10], Step [500/700], Loss: 0.9413
# Epoch [4/10], Step [600/700], Loss: 6.8471
# Epoch [4/10], Step [700/700], Loss: 0.5822
# Epoch [5/10], Step [100/700], Loss: 0.5068
# Epoch [5/10], Step [200/700], Loss: 0.3268
# Epoch [5/10], Step [300/700], Loss: 0.5223
# Epoch [5/10], Step [400/700], Loss: 1.7571
# Epoch [5/10], Step [500/700], Loss: 0.9268
# Epoch [5/10], Step [600/700], Loss: 6.8116
# Epoch [5/10], Step [700/700], Loss: 0.5612
# Epoch [6/10], Step [100/700], Loss: 0.4990
# Epoch [6/10], Step [200/700], Loss: 0.3170
# Epoch [6/10], Step [300/700], Loss: 0.5175
# Epoch [6/10], Step [400/700], Loss: 1.7361
# Epoch [6/10], Step [500/700], Loss: 0.9143
# Epoch [6/10], Step [600/700], Loss: 6.7902
# Epoch [6/10], Step [700/700], Loss: 0.5528
# Epoch [7/10], Step [100/700], Loss: 0.4955
# Epoch [7/10], Step [200/700], Loss: 0.3107
# Epoch [7/10], Step [300/700], Loss: 0.5171
# Epoch [7/10], Step [400/700], Loss: 1.7217
# Epoch [7/10], Step [500/700], Loss: 0.9066
# Epoch [7/10], Step [600/700], Loss: 6.7640
# Epoch [7/10], Step [700/700], Loss: 0.5477
# Epoch [8/10], Step [100/700], Loss: 0.4944
# Epoch [8/10], Step [200/700], Loss: 0.3076
# Epoch [8/10], Step [300/700], Loss: 0.5165
# Epoch [8/10], Step [400/700], Loss: 1.7129
# Epoch [8/10], Step [500/700], Loss: 0.9013
# Epoch [8/10], Step [600/700], Loss: 6.7482
# Epoch [8/10], Step [700/700], Loss: 0.5432
# Epoch [9/10], Step [100/700], Loss: 0.4930
# Epoch [9/10], Step [200/700], Loss: 0.3051
# Epoch [9/10], Step [300/700], Loss: 0.5167
# Epoch [9/10], Step [400/700], Loss: 1.7087
# Epoch [9/10], Step [500/700], Loss: 0.8993
# Epoch [9/10], Step [600/700], Loss: 6.7347
# Epoch [9/10], Step [700/700], Loss: 0.5437
# Epoch [10/10], Step [100/700], Loss: 0.4916
# Epoch [10/10], Step [200/700], Loss: 0.3038
# Epoch [10/10], Step [300/700], Loss: 0.5156
# Epoch [10/10], Step [400/700], Loss: 1.7070
# Epoch [10/10], Step [500/700], Loss: 0.8937
# Epoch [10/10], Step [600/700], Loss: 6.7324
# Epoch [10/10], Step [700/700], Loss: 0.5421

# %%
with torch.no_grad():
    X_ = X[:,0].reshape(len(X), 1)
    Y_ = X[:,1:3]
    test_ = torch.Tensor(X_)
    test_ = test_.reshape(-1, sequence_length, input_size).to(device)
    prediction_ = model(test_)
prediction = prediction_.detach().numpy()

# %%
ax = plt.figure(figsize = (13, 8))
ax = plt.axes(projection='3d')

ax.plot3D(X[:,0], prediction[:,0], prediction[:,1], 'b.', alpha=1, ms=2)
ax.plot3D(X[:,0], X[:,1], X[:,2], 'r.', alpha=0.1, ms=1)

ax.set_title('Power Curve')
ax.set_xlabel('Wind Speed')
ax.set_ylabel('Rotor Speed')
ax.set_zlabel('Grid Power')
#ax.set_xlabel('Rüzgar Hızı')
#ax.set_ylabel('Döneç Hızı')
#ax.set_zlabel('Üretilen Güç')

ax.view_init(azim=240)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("Rotor Speed Real and Generated")
plt.plot(X[:,1], 'b.', alpha=0.2, ms = 2, label = 'Test Data')
plt.plot(prediction[:,0], 'r.', alpha=0.2, ms = 2, label = 'LSTM Prediction')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("Grid Power Real and Generated")
plt.plot(X[:,2], 'b.', alpha=0.2, ms = 2, label = 'Test Data')
plt.plot(prediction[:,1], 'r.', alpha=0.2, ms = 2, label = 'LSTM Prediction')
plt.legend(loc='upper right')
plt.show()

# %%
E = X[:,1:3] - prediction
E_norm = np.linalg.norm(E, axis = 1)
plt.figure(figsize=(12,5))
plt.plot(E_norm)
plt.show()

# %%
smoothing_coefficient = 0.99
average = np.zeros(len(E_norm))
for i in range(len(E_norm)):
        if (i == 0):
            average[i] = E_norm[i]
        else:
            average[i] = average[i - 1]*smoothing_coefficient + E_norm[i]*(1 - smoothing_coefficient)

# %%
plt.figure(figsize=(15,5))
plt.title("Resulted Anomaly Graph")
plt.plot(E_norm,'b', alpha=0.4, ms = 2, label='Single Anomaly')
plt.plot(average, 'r', alpha=1, ms = 2, label='Collective Anomaly')
plt.legend(loc='upper right')
plt.show()
